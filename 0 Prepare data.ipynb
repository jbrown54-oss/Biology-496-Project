# %%
library(tidyverse)

source("R/prepare_data.R")

write_csv(gland_positions,  "data/gland_positions.csv")
write_csv(gland_areas,      "data/gland_areas.csv")
write_csv(cell_areas,       "data/cell_areas.csv")
write_csv(trichome_density, "data/trichome_density.csv")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.1     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.3     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
gland_positions %>% count(stage, image)
gland_areas     %>% count(stage)
cell_areas      %>% count(stage, zone, use)
trichome_density
# Out:
#   stage    image   n
# 1 immature istb50x 27
# 2 mature   msb50x  35
#   stage    n
# 1 immature 22
# 2 mature   30
#   stage    zone    use   n
# 1 immature throat   TRUE 13
# 2 mature   stomach FALSE 10
# 3 mature   throat   TRUE  9
#   zone    stage    count image   field_mm2 density_per_mm2
# 1 throat  immature 145   ithf50x 4.9152    29.500326
# 2 throat  mature    89   mthf50x 4.9152    18.107096
# 3 stomach immature  75   istf50x 4.9152    15.258789
# 4 stomach mature    40   msf50x  4.9152     8.138021
